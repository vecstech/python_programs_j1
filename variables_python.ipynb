# %% [markdown]
# # Variables In python
# 1. variables is memory allocation to value
# 2. examples are name="shivaji", age=26, salary=20000.65
#
# ## key points to define variables
# 1. varaible do not start with digit
# 2. variable does not allowed special charecters
# 3. do not use keywords as a variables

# %%
name="vikas"
age=20
salary=45000.65
print(name)
print(age)
print(salary)

# %%
1name="shivaji"
print(1name)

# %%
name@="vikas"
print(name@)

# %%
while = "shiva"
print(while)

# %%
while1 = "shiva"
print(while1)
